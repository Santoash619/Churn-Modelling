# %% [markdown]
# # CUSTOMER CHURN PREDICTION USING ANN

# %% [markdown]
# In this tutorial you will solve classification problem where in we have a dataset in which there are details of a bank's customers and the target variable is a binary variable reflecting the fact whether the customer left the bank (closed his account) or he continues to be a customer.

# %% [markdown]
# ## Importing Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir("/content/drive/MyDrive/Deep Learning Projects/Churn_Modeling")

# %%
# !dir
# Out:
# Churn_Modelling.csv  Classification-Using-ANN.ipynb  Untitled0.ipynb

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import tensorflow
from tensorflow.keras import Sequential
from tensorflow.keras import  callbacks
from tensorflow.keras.layers import Dense

import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error as mae
import seaborn as sns
# %matplotlib inline

#removing warnings
import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %%
print(tensorflow.__version__)
# Out:
# 2.15.0

# %% [markdown]
# ## Import Dataset

# %%
# Importing the dataset
df = pd.read_csv('Churn_Modelling.csv',index_col='RowNumber')
df.shape
# Out:
# (10000, 13)

# %%
df.head()
# Out:
#            CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# RowNumber
# 1            15634602  Hargrave          619    France  Female   42       2
# 2            15647311      Hill          608     Spain  Female   41       1
# 3            15619304      Onio          502    France  Female   42       8
# 4            15701354      Boni          699    France  Female   39       1
# 5            15737888  Mitchell          850     Spain  Female   43       2
#
#              Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# RowNumber
# 1               0.00              1          1               1
# 2           83807.86              1          0               1
# 3          159660.80              3          1               0
# 4               0.00              2          0               0
# 5          125510.82              1          1               1
#
#            EstimatedSalary  Exited
# RowNumber
# 1                101348.88       1
# 2                112542.58       0
# 3                113931.57       1
# 4                 93826.63       0
# 5                 79084.10       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10000 entries, 1 to 10000
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  object
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  object
#  4   Gender           10000 non-null  object
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# min         1.000000      0.00000        0.000000        11.580000
# 25%         1.000000      0.00000        0.000000     51002.110000
# 50%         1.000000      1.00000        1.000000    100193.915000
# 75%         2.000000      1.00000        1.000000    149388.247500
# max         4.000000      1.00000        1.000000    199992.480000
#
#              Exited
# count  10000.000000
# mean       0.203700
# std        0.402769
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
# some columns are totally unproductive so let's remove them
df.drop(['CustomerId','Surname'],axis=1,inplace=True)

# %%
# some columns have text data so let's one hot encode them
#  for more on one hot encoding click this link below
df = pd.get_dummies(prefix='Geo',data=df,columns=['Geography'])

# %%
df.head()
# Out:
#            CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  \
# RowNumber
# 1                  619  Female   42       2       0.00              1
# 2                  608  Female   41       1   83807.86              1
# 3                  502  Female   42       8  159660.80              3
# 4                  699  Female   39       1       0.00              2
# 5                  850  Female   43       2  125510.82              1
#
#            HasCrCard  IsActiveMember  EstimatedSalary  Exited  Geo_France  \
# RowNumber
# 1                  1               1        101348.88       1           1
# 2                  0               1        112542.58       0           0
# 3                  1               0        113931.57       1           1
# 4                  0               0         93826.63       0           1
# 5                  1               1         79084.10       0           0
#
#            Geo_Germany  Geo_Spain
# RowNumber
# 1                    0          0
# 2                    0          1
# 3                    0          0
# 4                    0          0
# 5                    0          1

# %%
df = df.replace(to_replace={'Gender': {'Female': 1,'Male':0}})

# %%
df.shape
# Out:
# (10000, 13)

# %%
sns.countplot(y=df.Exited ,data=df)
plt.xlabel("Count of each Target class")
plt.ylabel("Target classes")
plt.show()

# %%
df.hist(figsize=(15,12),bins = 15)
plt.title("Features Distribution")
plt.show()

# %%
plt.figure(figsize=(15,15))
p=sns.heatmap(df.corr(), annot=True,cmap='RdYlGn',center=0, vmax=1.0, vmin=-1.0)

# %%
fig,ax = plt.subplots(nrows = 4, ncols=3, figsize=(30,30))
row = 0
col = 0
for i in range(len(df.columns) -1):
    if col > 2:
        row += 1
        col = 0
    axes = ax[row,col]
    sns.boxplot(x = df['Exited'], y = df[df.columns[i]],ax = axes)
    col += 1
plt.tight_layout()
# plt.title("Individual Features by Class")
plt.show()

# %%
y = df.Exited
X = df.drop(['Exited'],axis=1)

# %%
# Splitting the dataset into the Training set and Test set

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 0)

# %%
# Feature Scaling because yes we don't want one independent variable dominating the other and it makes computations easy
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Deep learning

# %%
# sequential model to initialise our ann and dense module to build the layers
model = Sequential()

# Adding the input layer and the first hidden layer
model.add(Dense(units = 100,
                kernel_initializer = 'uniform',
                activation = 'relu',
                input_dim = 12))

model.add(Dense(units = 150,
                kernel_initializer = 'uniform',
                activation = 'relu'))

# Adding the output layer
model.add(Dense(units = 1,
                kernel_initializer = 'uniform',
                activation = 'sigmoid'))

# %%
# Compiling the ANN | means applying SGD on the whole ANN
model.compile(optimizer = 'adam',
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

# %%
model.summary()

# %%
# Fitting the ANN to the Training set
EPOCHS = 100
BATCH_SIZE  = 64 # 2, 4,8,16,32, 64, 128, 274

# train model
H = model.fit(X_train,
              y_train,
              batch_size = BATCH_SIZE,
              epochs = EPOCHS,
              validation_split=0.2,
              verbose = 1)

# %%
H.history

# %%
# plot the training and validation loss
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure(figsize = [10,8])
plt.plot(N, H.history["loss"], label="train_loss")
plt.plot(N, H.history["val_loss"], label="val_loss")
plt.title("ANN: Loss")
plt.xlabel("Epoch #", weight="bold")
plt.ylabel("Loss", weight="bold")
plt.legend()
plt.show()

# %%
# plot the training and validation accuracy
N = np.arange(0, EPOCHS)
plt.style.use("ggplot")
plt.figure(figsize = [10,8])
plt.plot(N, H.history["accuracy"], label="train_acc")
plt.plot(N, H.history["val_accuracy"], label="val_acc")
plt.title("ANN: Accuracy")
plt.xlabel("Epoch #", weight="bold")
plt.ylabel("Accuracy", weight="bold")
plt.legend()
plt.show()

# %%
score, acc = model.evaluate(X_train, y_train,
                            batch_size=10)
print('Train score:', score)
print('Train accuracy:', acc)

# %%
# Part 3 - Making predictions and evaluating the model

# Predicting the Test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)

print('*'*20)
score, acc = model.evaluate(X_test, y_test,
                            batch_size=10)
print('Test score:', score)
print('Test accuracy:', acc)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %% [markdown]
# <a id='11'></a>
# # 11. Evaluation Metrics

# %%
p = sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %%
from sklearn.metrics import roc_curve
y_pred_proba = model.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('ROC curve')
plt.show()
# Out:
# 104/104 [==============================] - 0s 1ms/step

# %%
#Area under ROC curve
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_pred_proba)
# Out:
# 0.8229204139394912

# %% [markdown]
# <a id='12'></a>
# # 12. Evaluation of Multiple Training Instances

# %%
# !pip install keras==2.12.0 # restart session after installing

# %%
# Part 4 - Evaluating, Improving and Tuning the ANN

# Evaluating the ANN
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from keras.models import Sequential
from keras.layers import Dense

def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier

classifier = KerasClassifier(build_fn = build_classifier, batch_size = 64, epochs = 50,verbose=1)
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10)
mean = accuracies.mean()
variance = accuracies.std()
# Out:
# <ipython-input-20-2f34193002ef>:17: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   classifier = KerasClassifier(build_fn = build_classifier, batch_size = 64, epochs = 50,verbose=1)
# Epoch 1/50
# 95/95 [==============================] - 2s 3ms/step - loss: 0.6686 - accuracy: 0.7990
# Epoch 2/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.5378 - accuracy: 0.7992
# Epoch 3/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.
50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.5293 - accuracy: 0.7970
# Epoch 3/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4509 - accuracy: 0.7970
# Epoch 4/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4394 - accuracy: 0.7970
# Epoch 5/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4353 - accuracy: 0.7970
# Epoch 6/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4326 - accuracy: 0.7970
# Epoch 7/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4310 - accuracy: 0.7970
# Epoch 8/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4297 - accuracy: 0.7970
# Epoch 9/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4287 - accuracy: 0.7970
# Epoch 10/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4277 - accuracy: 0.7970
# Epoch 11/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4268 - accuracy: 0.7970
# Epoch 12/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4258 - accuracy: 0.7970
# Epoch 13/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4246 - accuracy: 0.7970
# Epoch 14/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4234 - accuracy: 0.7970
# Epoch 15/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4224 - accuracy: 0.7970
# Epoch 16/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4217 - accuracy: 0.7970
# Epoch 17/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4208 - accuracy: 0.7970
# Epoch 18/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4201 - accuracy: 0.8045
# Epoch 19/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4194 - accuracy: 0.8151
# Epoch 20/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4192 - accuracy: 0.8169
# Epoch 21/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4186 - accuracy: 0.8161
# Epoch 22/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4178 - accuracy: 0.8186
# Epoch 23/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4173 - accuracy: 0.8194
# Epoch 24/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4168 - accuracy: 0.8231
# Epoch 25/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4163 - accuracy: 0.8227
# Epoch 26/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4159 - accuracy: 0.8254
# Epoch 27/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4154 - accuracy: 0.8252
# Epoch 28/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4151 - accuracy: 0.8264
# Epoch 29/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4146 - accuracy: 0.8289
# Epoch 30/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4142 - accuracy: 0.8287
# Epoch 31/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4141 - accuracy: 0.8277
# Epoch 32/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4134 - accuracy: 0.8269
# Epoch 33/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4131 - accuracy: 0.8302
# Epoch 34/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4128 - accuracy: 0.8300
# Epoch 35/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4126 - accuracy: 0.8300
# Epoch 36/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4124 - accuracy: 0.8302
# Epoch 37/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4118 - accuracy: 0.8295
# Epoch 38/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4117 - accuracy: 0.8308
# Epoch 39/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4114 - accuracy: 0.8303
# Epoch 40/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4113 - accuracy: 0.8322
# Epoch 41/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4107 - accuracy: 0.8323
# Epoch 42/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4107 - accuracy: 0.8323
# Epoch 43/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4105 - accuracy: 0.8307
# Epoch 44/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4104 - accuracy: 0.8320
# Epoch 45/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.8318
# Epoch 46/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4100 - accuracy: 0.8330
# Epoch 47/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4097 - accuracy: 0.8325
# Epoch 48/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4093 - accuracy: 0.8327
# Epoch 49/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4090 - accuracy: 0.8342
# Epoch 50/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.8330
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3936 - accuracy: 0.8403
# Epoch 1/50
# 95/95 [==============================] - 1s 3ms/step - loss: 0.6698 - accuracy: 0.7955
# Epoch 2/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.5461 - accuracy: 0.7992
# Epoch 3/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4505 - accuracy: 0.7992
# Epoch 4/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4374 - accuracy: 0.7992
# Epoch 5/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4335 - accuracy: 0.7992
# Epoch 6/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4309 - accuracy: 0.7992
# Epoch 7/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4290 - accuracy: 0.7992
# Epoch 8/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.
50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4223 - accuracy: 0.7993
# Epoch 10/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4201 - accuracy: 0.7993
# Epoch 11/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4180 - accuracy: 0.7993
# Epoch 12/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4160 - accuracy: 0.8136
# Epoch 13/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4142 - accuracy: 0.8209
# Epoch 14/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4125 - accuracy: 0.8232
# Epoch 15/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4108 - accuracy: 0.8279
# Epoch 16/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4093 - accuracy: 0.8299
# Epoch 17/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4080 - accuracy: 0.8310
# Epoch 18/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4068 - accuracy: 0.8335
# Epoch 19/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4054 - accuracy: 0.8337
# Epoch 20/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4044 - accuracy: 0.8340
# Epoch 21/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4034 - accuracy: 0.8333
# Epoch 22/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4026 - accuracy: 0.8348
# Epoch 23/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4018 - accuracy: 0.8355
# Epoch 24/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4014 - accuracy: 0.8353
# Epoch 25/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4004 - accuracy: 0.8345
# Epoch 26/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.3999 - accuracy: 0.8342
# Epoch 27/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.3992 - accuracy: 0.8365
# Epoch 28/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.3988 - accuracy: 0.8371
# Epoch 29/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.3982 - accuracy: 0.8357
# Epoch 30/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3977 - accuracy: 0.8367
# Epoch 31/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3974 - accuracy: 0.8378
# Epoch 32/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3969 - accuracy: 0.8362
# Epoch 33/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3970 - accuracy: 0.8363
# Epoch 34/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3966 - accuracy: 0.8362
# Epoch 35/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3961 - accuracy: 0.8365
# Epoch 36/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3960 - accuracy: 0.8368
# Epoch 37/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3956 - accuracy: 0.8362
# Epoch 38/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3955 - accuracy: 0.8378
# Epoch 39/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3953 - accuracy: 0.8365
# Epoch 40/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3949 - accuracy: 0.8367
# Epoch 41/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3948 - accuracy: 0.8371
# Epoch 42/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3947 - accuracy: 0.8367
# Epoch 43/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3947 - accuracy: 0.8370
# Epoch 44/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3941 - accuracy: 0.8373
# Epoch 45/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3940 - accuracy: 0.8373
# Epoch 46/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.3938 - accuracy: 0.8365
# Epoch 47/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3935 - accuracy: 0.8367
# Epoch 48/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3935 - accuracy: 0.8378
# Epoch 49/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.8385
# Epoch 50/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3927 - accuracy: 0.8373
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4269 - accuracy: 0.8254
# Epoch 1/50
# 95/95 [==============================] - 1s 3ms/step - loss: 0.6594 - accuracy: 0.7995
# Epoch 2/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.5011 - accuracy: 0.7995
# Epoch 3/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4430 - accuracy: 0.7995
# Epoch 4/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4360 - accuracy: 0.7995
# Epoch 5/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4325 - accuracy: 0.7995
# Epoch 6/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4301 - accuracy: 0.7995
# Epoch 7/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4284 - accuracy: 0.7995
# Epoch 8/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0
50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4040 - accuracy: 0.8370
# Epoch 50/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4039 - accuracy: 0.8362
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4127 - accuracy: 0.8254
# Epoch 1/50
# 95/95 [==============================] - 1s 3ms/step - loss: 0.6701 - accuracy: 0.7939
# Epoch 2/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.5474 - accuracy: 0.7980
# Epoch 3/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4493 - accuracy: 0.7980
# Epoch 4/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4355 - accuracy: 0.7980
# Epoch 5/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4310 - accuracy: 0.7980
# Epoch 6/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4278 - accuracy: 0.7980
# Epoch 7/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4247 - accuracy: 0.7980
# Epoch 8/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4227 - accuracy: 0.7980
# Epoch 9/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4204 - accuracy: 0.7980
# Epoch 10/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4183 - accuracy: 0.7980
# Epoch 11/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4164 - accuracy: 0.8113
# Epoch 12/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4143 - accuracy: 0.8206
# Epoch 13/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4125 - accuracy: 0.8254
# Epoch 14/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4109 - accuracy: 0.8249
# Epoch 15/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4093 - accuracy: 0.8313
# Epoch 16/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4080 - accuracy: 0.8318
# Epoch 17/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4070 - accuracy: 0.8315
# Epoch 18/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4057 - accuracy: 0.8327
# Epoch 19/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4046 - accuracy: 0.8327
# Epoch 20/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4037 - accuracy: 0.8313
# Epoch 21/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4031 - accuracy: 0.8328
# Epoch 22/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4020 - accuracy: 0.8328
# Epoch 23/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.4012 - accuracy: 0.8323
# Epoch 24/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4006 - accuracy: 0.8327
# Epoch 25/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3999 - accuracy: 0.8343
# Epoch 26/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3995 - accuracy: 0.8342
# Epoch 27/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3990 - accuracy: 0.8340
# Epoch 28/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3982 - accuracy: 0.8352
# Epoch 29/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3978 - accuracy: 0.8337
# Epoch 30/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3973 - accuracy: 0.8353
# Epoch 31/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3969 - accuracy: 0.8370
# Epoch 32/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3966 - accuracy: 0.8357
# Epoch 33/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3962 - accuracy: 0.8365
# Epoch 34/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3959 - accuracy: 0.8350
# Epoch 35/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3953 - accuracy: 0.8358
# Epoch 36/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3951 - accuracy: 0.8367
# Epoch 37/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3949 - accuracy: 0.8367
# Epoch 38/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3948 - accuracy: 0.8367
# Epoch 39/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3943 - accuracy: 0.8365
# Epoch 40/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3943 - accuracy: 0.8376
# Epoch 41/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3940 - accuracy: 0.8370
# Epoch 42/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3937 - accuracy: 0.8362
# Epoch 43/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3933 - accuracy: 0.8373
# Epoch 44/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3933 - accuracy: 0.8381
# Epoch 45/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3929 - accuracy: 0.8360
# Epoch 46/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3928 - accuracy: 0.8371
# Epoch 47/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3927 - accuracy: 0.8380
# Epoch 48/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3925 - accuracy: 0.8373
# Epoch 49/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3923 - accuracy: 0.8373
# Epoch 50/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.3925 - accuracy: 0.8376
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4370 - accuracy: 0.8104
# Epoch 1/50
# 95/95 [==============================] - 1s 3ms/step - loss: 0.6653 - accuracy: 0.7947
# Epoch 2/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.5247 - accuracy: 0.7980
# Epoch 3/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4522 - accuracy: 0.7980
# Epoch 4/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4421 - accuracy: 0.7980
# Epoch 5/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4360 - accuracy: 0.7980
# Epoch 6/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4327 - accuracy: 0.7980
# Epoch 7/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4307 - accuracy: 0.7980
# Epoch 8/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4291 - accuracy: 0.7980
# Epoch 9/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4280 - accuracy: 0.7980
# Epoch 10/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4272 - accuracy: 0.7980
# Epoch 11/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4264 - accuracy: 0.7980
# Epoch 12/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4254 - accuracy: 0.7980
# Epoch 13/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4244 - accuracy: 0.7980
# Epoch 14/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4234 - accuracy: 0.7980
# Epoch 15/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4221 - accuracy: 0.7980
# Epoch 16/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4210 - accuracy: 0.7980
# Epoch 17/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4197 - accuracy: 0.7980
# Epoch 18/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4186 - accuracy: 0.7980
# Epoch 19/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4177 - accuracy: 0.8129
# Epoch 20/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4169 - accuracy: 0.8177
# Epoch 21/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4163 - accuracy: 0.8197
# Epoch 22/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4155 - accuracy: 0.8221
# Epoch 23/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4151 - accuracy: 0.8209
# Epoch 24/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4142 - accuracy: 0.8237
# Epoch 25/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4137 - accuracy: 0.8237
# Epoch 26/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4134 - accuracy: 0.8255
# Epoch 27/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4128 - accuracy: 0.8260
# Epoch 28/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4123 - accuracy: 0.8289
# Epoch 29/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4120 - accuracy: 0.8275
# Epoch 30/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4116 - accuracy: 0.8285
# Epoch 31/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4110 - accuracy: 0.8289
# Epoch 32/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4109 - accuracy: 0.8295
# Epoch 33/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4105 - accuracy: 0.8299
# Epoch 34/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4100 - accuracy: 0.8303
# Epoch 35/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.4095 - accuracy: 0.8313
# Epoch 36/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4096 - accuracy: 0.8318
# Epoch 37/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4091 - accuracy: 0.8323
# Epoch 38/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4090 - accuracy: 0.8325
# Epoch 39/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8338
# Epoch 40/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4081 - accuracy: 0.8333
# Epoch 41/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4078 - accuracy: 0.8327
# Epoch 42/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4076 - accuracy: 0.8327
# Epoch 43/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4074 - accuracy: 0.8332
# Epoch 44/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4071 - accuracy: 0.8327
# Epoch 45/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4068 - accuracy: 0.8330
# Epoch 46/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4065 - accuracy: 0.8337
# Epoch 47/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4062 - accuracy: 0.8343
# Epoch 48/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4060 - accuracy: 0.8337
# Epoch 49/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4057 - accuracy: 0.8335
# Epoch 50/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4055 - accuracy: 0.8337
# 11/11 [==============================] - 0s 3ms/step - loss: 0.4047 - accuracy: 0.8328
# Epoch 1/50
# 95/95 [==============================] - 1s 3ms/step - loss: 0.6625 - accuracy: 0.7962
# Epoch 2/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.5128 - accuracy: 0.7973
# Epoch 3/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4430 - accuracy: 0.7973
# Epoch 4/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4351 - accuracy: 0.7973
# Epoch 5/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4317 - accuracy: 0.7973
# Epoch 6/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4294 - accuracy: 0.7973
# Epoch 7/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4281 - accuracy: 0.7973
# Epoch 8/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4270 - accuracy: 0.7973
# Epoch 9/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4262 - accuracy: 0.7973
# Epoch 10/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4253 - accuracy: 0.7973
# Epoch 11/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4244 - accuracy: 0.7973
# Epoch 12/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4236 - accuracy: 0.7973
# Epoch 13/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4226 - accuracy: 0.7973
# Epoch 14/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4218 - accuracy: 0.7973
# Epoch 15/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.4213 - accuracy: 0.7973
# Epoch 16/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4204 - accuracy: 0.7973
# Epoch 17/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4202 - accuracy: 0.8063
# Epoch 18/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4192 - accuracy: 0.8136
# Epoch 19/50
# 95/95 [==============================] - 1s 5ms/step - loss: 0.4188 - accuracy: 0.8179
# Epoch 20/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4180 - accuracy: 0.8174
# Epoch 21/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4176 - accuracy: 0.8177
# Epoch 22/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4169 - accuracy: 0.8186
# Epoch 23/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4165 - accuracy: 0.8214
# Epoch 24/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4158 - accuracy: 0.8221
# Epoch 25/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4153 - accuracy: 0.8235
# Epoch 26/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4145 - accuracy: 0.8252
# Epoch 27/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4140 - accuracy: 0.8264
# Epoch 28/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4134 - accuracy: 0.8264
# Epoch 29/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4132 - accuracy: 0.8284
# Epoch 30/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4125 - accuracy: 0.8284
# Epoch 31/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4119 - accuracy: 0.8270
# Epoch 32/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4117 - accuracy: 0.8294
# Epoch 33/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4113 - accuracy: 0.8307
# Epoch 34/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4110 - accuracy: 0.8299
# Epoch 35/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4108 - accuracy: 0.8323
# Epoch 36/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4102 - accuracy: 0.8318
# Epoch 37/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4099 - accuracy: 0.8318
# Epoch 38/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4094 - accuracy: 0.8327
# Epoch 39/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4095 - accuracy: 0.8327
# Epoch 40/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4091 - accuracy: 0.8337
# Epoch 41/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4086 - accuracy: 0.8337
# Epoch 42/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8347
# Epoch 43/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4080 - accuracy: 0.8340
# Epoch 44/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4083 - accuracy: 0.8327
# Epoch 45/50
# 95/95 [==============================] - 0s 3ms/step - loss: 0.4075 - accuracy: 0.8333
# Epoch 46/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4075 - accuracy: 0.8343
# Epoch 47/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.8335
# Epoch 48/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4069 - accuracy: 0.8353
# Epoch 49/50
# 95/95 [==============================] - 0s 4ms/step - loss: 0.4066 - accuracy: 0.8352
# Epoch 50/50
# 95/95 [==============================] - 0s 5ms/step - loss: 0.4062 - accuracy: 0.8358
# 11/11 [==============================] - 0s 3ms/step - loss: 0.3983 - accuracy: 0.8388

# %%
print('Mean accuracy score of 10 different models using Kfold cross validation: {}'.format(mean))
print('Standard Deviation of accuracy score of 10 different models using Kfold cross validation: {}'.format(variance))
# Out:
# Mean accuracy score of 10 different models using Kfold cross validation: 0.836119395494461
# Standard Deviation of accuracy score of 10 different models using Kfold cross validation: 0.015232666969612833

# %% [markdown]
# #### Deviation is very low so I'd say that it is unlikely to be an overfitted model. With different training sets it got the mean with all training results is still very close to the above model.

# %% [markdown]
# <a id='13'></a>
# # 13. Improving ANN with Dropout layer

# %% [markdown]
# #### Dropout Regularization is used to reduce overfitting if needed.
#
# #### p is the fraction of input units to drop. If suppose there are ten neurons from a layer and p is 0.1 then one of the neurons would be disabled and its output would not be sent to the further layer.
# #### It is advisable to start with p 0.1 and move to higher values when in case the overfitting problem persists. Also going over 0.5 is not advisable generally because it may cause underfitting as most of the neurons are disabled.

# %%
# Improving the ANN
from tensorflow.keras.layers import Dropout
classifier = Sequential()
# Adding the input layer and the first hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
classifier.add(Dropout(rate = 0.1))

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
classifier.add(Dropout(rate = 0.1))

# Adding the output layer
classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 64, epochs = 50,verbose = 1)

# %%
# Part 3 - Making predictions and evaluating the model

score, acc = classifier.evaluate(X_train, y_train,
                            batch_size=10)
print('Train score:', score)
print('Train accuracy:', acc)
# Part 3 - Making predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

print('*'*20)
score, acc = classifier.evaluate(X_test, y_test,
                            batch_size=10)
print('Test score:', score)
print('Test accuracy:', acc)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
p = sns.heatmap(pd.DataFrame(cm), annot=True, cmap="YlGnBu" ,fmt='g')
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# %%
#import classification_report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))

# %%
from sklearn.metrics import roc_curve
y_pred_proba = classifier.predict(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_proba)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr, label='ANN')
plt.xlabel('fpr')
plt.ylabel('tpr')
plt.title('ROC curve')
plt.show()

# %%
#Area under ROC curve
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,y_pred_proba)

# %% [markdown]
# # Tuning the ANN

# %% [markdown]
# #### Let's test 2 values of the batch size and we're gonna try 25 and 32. So why 25 and 32? Well, that's based on my experience and that's also common practice to take powers of 2. Well, you can try other values of the batch size as well.

# %%
# Tuning the ANN
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import GridSearchCV
from keras.models import Sequential
from keras.layers import Dense
def build_classifier(optimizer):
    classifier = Sequential()
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
    classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))
    classifier.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    classifier.compile(optimizer = optimizer, loss = 'binary_crossentropy', metrics = ['accuracy'])
    return classifier
classifier = KerasClassifier(build_fn = build_classifier)
parameters = {'batch_size': [25, 32],
              'epochs': [100, 200],
              'optimizer': ['adam', 'rmsprop']}
grid_search = GridSearchCV(estimator = classifier,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10)
grid_search = grid_search.fit(X_train, y_train,verbose = 0)
best_parameters = grid_search.best_params_
best_accuracy = grid_search.best_score_

# %%
print('Best Parameters after tuning: {}'.format(best_parameters))
print('Best Accuracy after tuning: {}'.format(best_accuracy))
